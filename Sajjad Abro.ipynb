# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/data_for_exam.xlsx - Sheet1.csv')
df
# Out:
#    Date received                                            Product  \
# 0      3/12/2014                                           Mortgage
# 1      1/19/2017                                       Student loan
# 2       4/6/2018                        Credit card or prepaid card
# 3       6/8/2014                                        Credit card
# 4      9/13/2014                                    Debt collection
# ..           ...                                                ...
# 94     2/10/2015                                    Money transfers
# 95     1/20/2015                                           Mortgage
# 96     8/15/2018  Money transfer, virtual currency, or money ser...
# 97     1/29/2017                                   Credit reporting
# 98    11/18/2014                                    Debt collection
#
#                                  Other product  \
# 0                               Other mortgage
# 1               Federal student loan servicing
# ...

# %%
df.isnull().sum()
# Out:
# Date received                    0
# Product                          0
# Other product                    0
# Consumer complaint narrative    83
# Company public response         66
# Company                          0
# State                            0
# ZIP code                         0
# Submitted via                    0
# Company response to consumer     0
# Timely response?                 0
# Consumer disputed?              24
# dtype: int64

# %%
df['Company public response'].value_counts()
# Out:
# Company has responded to the consumer and the CFPB and chooses not to provide a public response    21
# Company believes it acted appropriately as authorized by contract or law                            9
# Company chooses not to provide a public response                                                    1
# Company can't verify or dispute the facts in the complaint                                          1
# Company believes the complaint is the result of a misunderstanding                                  1
# Name: Company public response, dtype: int64

# %%
df['Consumer complaint narrative'].fillna('Consumer have Complaint',inplace=True)
df['Consumer disputed?'].fillna('No',inplace=True)
df['Company public response'].fillna('Company working as Contract & law',inplace=True)

# %%
df.isnull().sum()
# Out:
# Date received                   0
# Product                         0
# Other product                   0
# Consumer complaint narrative    0
# Company public response         0
# Company                         0
# State                           0
# ZIP code                        0
# Submitted via                   0
# Company response to consumer    0
# Timely response?                0
# Consumer disputed?              0
# dtype: int64

# %%
df['Product']=le.fit_transfome(df['Product'])
df
